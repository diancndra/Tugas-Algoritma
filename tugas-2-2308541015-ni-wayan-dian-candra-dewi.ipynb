# %%
nama = "Dian_Candra_015"
print(nama)
# Out:
# Dian_Candra_015

# %%
nama = "haechan"
hewan = "kucing"
alasan = "lucu bangett"
print (nama + " hewan kesukaannya adalah " + hewan + " karena " + alasan + ".")
# Out:
# haechan hewan kesukaannya adalah kucing karena lucu bangett.

# %%
nama.upper()
# Out:
# 'HAECHAN'

# %%
kelas = "aku suka menari tarian tradisional"
print(kelas[2:10])
# Out:
# u suka m

# %%
kelas.find("tradisional")
# Out:
# 23

# %%
print ("Menari" in kelas)
# Out:
# False

# %%
print (23*56)
print (17*9+10/8)
print (8%6+15**2)
# Out:
# 1288
# 154.25
# 227

# %%
x = 2
y = 3
print (x > y)
# Out:
# False

# %%
umur_johnny = 30
umur_mark = 26
umur_andy = 22
print (umur_johnny < 40 or umur_mark > 26)
# Out:
# True
