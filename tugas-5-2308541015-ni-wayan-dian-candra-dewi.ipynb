# %%
data_15 = [1,2,3,4,5,6,7]
angka_15 = []
for anggota_15 in data_15:
  if anggota_15 not in angka_15:
    angka_15.append(data_15)
    print(anggota_15)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
matrik_15 = [
    [2,3],
    [4,5]
]
print (matrik_15[0][0]),
print (matrik_15[0][1]),
print (matrik_15[1][0]),
print (matrik_15[1][1])
# Out:
# 2
# 3
# 4
# 5

# %%
terbesar_15 = matrik_15[0]
for data_15 in matrik_15:
  if data_15 > terbesar_15:
    terbesar_15 = data_15
print(terbesar_15)

print ("------")

terkecil_15 = matrik_15[0]
for data_15 in matrik_15:
  if data_15 < terkecil_15:
    terkecil_15 = data_15
print(terkecil_15)
# Out:
# [4, 5]
# ------
# [2, 3]

# %%
def diagonal_utama_15(matrik_15):
  diagonal_utama_15 = float(matrik_15[0][0]*matrik_15[1][1])
  return diagonal_utama_15
def diagonal_lain_15(matrik_15):
  diagonal_lain_15 = float(matrik_15[0][1]*matrik_15[1][0])
  return diagonal_lain_15

diagonal_utama_15 = float(matrik_15[0][0])*float(matrik_15[1][1])
diagonal_lain_15 = float(matrik_15[0][1])*float(matrik_15[1][0])
for determinan_15 in matrik_15:
  hitung_15 = float(diagonal_utama_15)-float(diagonal_lain_15)
print ("Determinan matriknya adalah: " + str(hitung_15))
# Out:
# Determinan matriknya adalah: -2.0

# %%
tujuan_15 = "Ayo lebih dekat dengan Haechan NCT!"
print (tujuan_15)

print ("-------------------------------------")

data_orang_15 = {
    "nama_asli_15": "Lee Donghyuk",
    "nama_panggung_15":"Lee Haechan",
    "umur_15": "24",
    "tanggal_lahir_15": "06-06-2000",
    "apakah_single_15": "true",
}
print(data_orang_15["nama_asli_15"]),
print(data_orang_15["nama_panggung_15"]),
print(data_orang_15["umur_15"]),
print(data_orang_15["tanggal_lahir_15"]),
print(data_orang_15["apakah_single_15"])
# Out:
# Ayo lebih dekat dengan Haechan NCT!
# -------------------------------------
# Lee Donghyuk
# Lee Haechan
# 24
# 06-06-2000
# true

# %%
angka_15 = {
    "0" : "nol",
    "1" : "satu",
    "2" : "dua",
    "3" : "tiga",
    "4" : "empat",
    "5" : "lima",
    "6" : "enam",
    "7" : "tujuh",
    "8" : "delapan",
    "9" : "sembilan",
}

# %%
nim_15 = input("masukkan nim anda: ")
nomor_angka_15 =  ""
for data_15 in nim_15:
  nomor_angka_15 += angka_15.get(data_15) + " "
print(nomor_angka_15)
# Out:
# masukkan nim anda: 2308541015
# dua tiga nol delapan lima empat satu nol satu lima

# %%
def luas_segitiga_15(alas_15, tinggi_15):
   luas_15 = (float(alas_15*tinggi_15)/2)
alas_15 = input("Masukkan alas: ")
lebar_15 = input("Masukkan tinggi: ")
hitung_15 = (float(alas_15)*float(lebar_15)/2)
print ("Luas segitiganya adalah: " + str(hitung_15) + "cm²")
# Out:
# Masukkan alas: 8
# Masukkan tinggi: 16
# Luas segitiganya adalah: 64.0cm²
